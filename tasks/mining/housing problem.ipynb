# %% [markdown]
# 전체적인 작업 overview
#
# 매물 데이터를 활용해서,
# * 원하는 지역에 매물이 있는지 확인을 한다
# * 시세를 대강 파악 한다
# * 올라오지 않은 매물에 대한 정보 수집 할 때 비교해본다
# * 추천 받을 때 주변과 비교해본다

# %%
import pandas as pd
import time
import re
import requests
from bs4 import BeautifulSoup

# %%
import time, sys
from IPython.display import clear_output

def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
    
    block = int(round(bar_length * progress))
    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
def pretty_html(url):
    
    response = requests.request('GET', url)
    html_doc = response.text

    soup = BeautifulSoup(html_doc, 'html.parser')
    result_text = soup.prettify()
    return soup, result_text

# %%
def explore_home(url):
    """

    :return:
    """

    soup, result_text = pretty_html(url)

    pagenation_html = soup.findAll("a", {"data-ci-pagination-page" : True})
    max_num = pagenation_html[len(pagenation_html)-1]['data-ci-pagination-page']

    return max_num

# %%
def extract_detail_nums(url):
    
    _, result_text = pretty_html(url)

    details = []
    for line in result_text.split('\n'):

        # extract detail
        match = re.search(r'\/CProperty\/detail\?num=(\d+)', line)
        if match:
            detail_url = match.group()
            detail_num = match.group(1)
            details.append(detail_num)

    return details

# %%
def extract_latlng_with_detail(html_doc):
    """

    :return:
    """

    lat_num = None
    lng_num = None
    for line in html_doc.split('\n'):
        match = re.search(r'LatLng\(([\d.]+), ([\d.]+)\)', line)
        if match:
            lat_num = match.group(1)
            lng_num = match.group(2)
            break
    return lat_num, lng_num

# %%
def extract_detail_info(soup):
    
    title_html = soup.findAll("td", class_="info_t_cont")
    if len(title_html) > 0:
        title = title_html[0].getText().strip()
    else:
        title = ''

    category_html = soup.findAll("span", class_="detail_cate")
    if len(category_html) > 0:
        category = category_html[0].getText().strip()
    else:
        category = ''

    cost_type_html = soup.findAll("span", class_=re.compile("type*"))
    if len(cost_type_html) > 0:
        cost_type = cost_type_html[0].getText().strip()
    else:
        cost_type = ''

    price_html = soup.findAll("strong", class_="red")
    
    if len(price_html) > 0:
        price = price_html[0].getText().strip()
    else:
        price = ''

    sup_size_html = soup.find(id="sup_area_m")
    sup_size = None
    if sup_size_html:
        sup_size = sup_size_html['value']

    dedi_size_html = soup.find(id="dedi_area_m")
    dedi_size = None
    if dedi_size_html:
        dedi_size = dedi_size_html['value']

    item = {
        'category': category,
        'cost_type': cost_type,
        'price': price,
        'sup_size': sup_size,
        'dedi_size': dedi_size,
        'title': title
    }
    
    return item

# %%
def explore_detail(detail_num):
    
    home_url = 'https://www.jejuall.com'
    detail_url = '/CProperty/detail?num='
    
    print(home_url+detail_url+detail_num)
    soup, result_text = pretty_html(home_url+detail_url+detail_num)
    
    item = extract_detail_info(soup)
    lat_num, lng_num = extract_latlng(result_text)
    item['lat_num'] = lat_num
    item['lng_num'] = lng_num
    item['detail_num'] = detail_num
    
    return item

# %%
def execute(details):
    
    result = []
    
    number_of_elements = len(details)
    
    for idx, detail_num in enumerate(details):
        item = explore_detail(detail_num)
        result.append(item)
        
        print(idx, '/' ,number_of_elements)
        
        time.sleep(2)

    return result

# %%
explore_detail('1115710')
# Out:
# {'category': '상가점포',
#  'cost_type': '임대',
#  'price': '700/400',
#  'sup_size': '43',
#  'dedi_size': '43',
#  'title': '★SR-374(이도동상가) 중소기업청부근 아담한1층 상가임대★',
#  'lat_num': None,
#  'lng_num': None}

# %%
home_url = 'https://www.jejuall.com/CProperty/'
max_num = explore_home(home_url)

# %%
max_num
# Out:
# '157'

# %%
all_dup_details = []

# %%
page_url = 'https://www.jejuall.com/CProperty/index/params/category/NO/sort/1/sido/NO/dong/NO/small_area/0/big_area/1000000/small_price/0/big_price/1000000/keyword/NO/page1/1/page/'
number_of_elements = int(max_num)+1

for i in range(1, number_of_elements):
    page_url = page_url + str(i)
    raw_details = extract_detail_nums(page_url)
    all_dup_details.extend(raw_details)
    update_progress(i / number_of_elements)
    print(i, min(raw_details), max(raw_details), len(raw_details), len(list(set(raw_details))))
# Out:
# Progress: [####################] 99.4%
# 157 0 0

# %%
print(len(all_dup_details))
# Out:
# 5309

# %%
pd.Series(all_dup_details).value_counts()
# Out:
# 1115786    32
# 1094057    28
# 1114736    28
# 819240     28
# 1114099    28
#            ..
# 1115444     1
# 1111455     1
# 1115476     1
# 1111407     1
# 1115806     1
# Length: 276, dtype: int64

# %%
all_details = list(set(all_dup_details))
sample = list(map(lambda x: int(x), all_details))

# %%
max(sample)
# Out:
# 1115806

# %%
all_results = []
result = execute(all_details)
all_results.extend(result)
# Out:
# https://www.jejuall.com/CProperty/detail?num=1111441
# 0 / 276
# https://www.jejuall.com/CProperty/detail?num=1115790
# 1 / 276
# https://www.jejuall.com/CProperty/detail?num=955319
# 2 / 276
# https://www.jejuall.com/CProperty/detail?num=1115457
# 3 / 276
# https://www.jejuall.com/CProperty/detail?num=1111965
# 4 / 276
# https://www.jejuall.com/CProperty/detail?num=1115789
# 5 / 276
# https://www.jejuall.com/CProperty/detail?num=807374
# 6 / 276
# https://www.jejuall.com/CProperty/detail?num=1099456
# 7 / 276
# https://www.jejuall.com/CProperty/detail?num=1096048
# 8 / 276
# https://www.jejuall.com/CProperty/detail?num=1115467
# 9 / 276
# https://www.jejuall.com/CProperty/detail?num=812060
# 10 / 276
# https://www.jejuall.com/CProperty/detail?num=1016291
# 11 / 276
# https://www.jejuall.com/CProperty/detail?num=1005888
# 12 / 276
# https://www.jejuall.com/CProperty/detail?num=1103218
# 13 / 276
# https://www.jejuall.com/CProperty/detail?num=1099914
# 14 / 276
# https://www.jejuall.com/CProperty/detail?num=1115804
# 15 / 276
# https://www.jejuall.com/CProperty/detail?num=1115473
# 16 / 276
# https://www.jejuall.com/CProperty/detail?num=1111407
# 17 / 276
# https://www.jejuall.com/CProperty/detail?num=1111533
# 18 / 276
# https://www.jejuall.com/CProperty/detail?num=988201
# 19 / 276
# https://www.jejuall.com/CProperty/detail?num=1050376
# 20 / 276
# https://www.jejuall.com/CProperty/detail?num=1111497
# 21 / 276
# https://www.jejuall.com/CProperty/detail?num=1111562
# 22 / 276
# https://www.jejuall.com/CProperty/detail?num=1111408
# 23 / 276
# https://www.jejuall.com/CProperty/detail?num=1114876
# 24 / 276
# https://www.jejuall.com/CProperty/detail?num=1105022
# 25 / 276
# https://www.jejuall.com/CProperty/detail?num=1058020
# 26 / 276
# https://www.jejuall.com/CProperty/detail?num=1110776
# 27 / 276
# https://www.jejuall.com/CProperty/detail?num=1009818
# 28 / 276
# https://www.jejuall.com/CProperty/detail?num=1084610
# 29 / 276
# https://www.jejuall.com/CProperty/detail?num=853968
# 30 / 276
# https://www.jejuall.com/CProperty/detail?num=1114504
# 31 / 276
# https://www.jejuall.com/CProperty/detail?num=1112655
# 32 / 276
# https://www.jejuall.com/CProperty/detail?num=1042296
# 33 / 276
# https://www.jejuall.com/CProperty/detail?num=750757
# 34 / 276
# https://www.jejuall.com/CProperty/detail?num=1115795
# 35 / 276
# https://www.jejuall.com/CProperty/detail?num=1100688
# 36 / 276
# https://www.jejuall.com/CProperty/detail?num=1115446
# 37 / 276
# https://www.jejuall.com/CProperty/detail?num=1111430
# 38 / 276
# https://www.jejuall.com/CProperty/detail?num=1111411
# 39 / 276
# https://www.jejuall.com/CProperty/detail?num=1115464
# 40 / 276
# https://www.jejuall.com/CProperty/detail?num=1115445
# 41 / 276
# https://www.jejuall.com/CProperty/detail?num=1111433
# 42 / 276
# https://www.jejuall.com/CProperty/detail?num=439195
# 43 / 276
# https://www.jejuall.com/CProperty/detail?num=1115788
# 44 / 276
# https://www.jejuall.com/CProperty/detail?num=777334
# 45 / 276
# https://www.jejuall.com/CProperty/detail?num=1115783
# 46 / 276
# https://www.jejuall.com/CProperty/detail?num=1095027
# 47 / 276
# https://www.jejuall.com/CProperty/detail?num=867465
# 48 / 276
# https://www.jejuall.com/CProperty/detail?num=1115352
# 49 / 276
# https://www.jejuall.com/CProperty/detail?num=1040944
# 50 / 276
# https://www.jejuall.com/CProperty/detail?num=879259
# 51 / 276
# https://www.jejuall.com/CProperty/detail?num=1111452
# 52 / 276
# https://www.jejuall.com/CProperty/detail?num=1099045
# 53 / 276
# https://www.jejuall.com/CProperty/detail?num=1115777
# 54 / 276
# https://www.jejuall.com/CProperty/detail?num=1102817
# 55 / 276
# https://www.jejuall.com/CProperty/detail?num=1033484
# 56 / 276
# https://www.jejuall.com/CProperty/detail?num=1111443
# 57 / 276
# https://www.jejuall.com/CProperty/detail?num=1115456
# 58 / 276
# https://www.jejuall.com/CProperty/detail?num=1115798
# 59 / 276
# https://www.jejuall.com/CProperty/detail?num=1115786
# 60 / 276
# https://www.jejuall.com/CProperty/detail?num=895003
# 61 / 276
# https://www.jejuall.com/CProperty/detail?num=1058977
# 62 / 276
# https://www.jejuall.com/CProperty/detail?num=1050002
# 63 / 276
# https://www.jejuall.com/CProperty/detail?num=1107878
# 64 / 276
# https://www.jejuall.com/CProperty/detail?num=1109094
# 65 / 276
# https://www.jejuall.com/CProperty/detail?num=1108553
# 66 / 276
# https://www.jejuall.com/CProperty/detail?num=1074641
# 67 / 276
# https://www.jejuall.com/CProperty/detail?num=1111380
# 68 / 276
# https://www.jejuall.com/CProperty/detail?num=1115460
# 69 / 276
# https://www.jejuall.com/CProperty/detail?num=900600
# 70 / 276
# https://www.jejuall.com/CProperty/detail?num=604415
# 71 / 276
# https://www.jejuall.com/CProperty/detail?num=1053475
# 72 / 276
# https://www.jejuall.com/CProperty/detail?num=1112658
# 73 / 276
# https://www.jejuall.com/CProperty/detail?num=1112745
# 74 / 276
# https://www.jejuall.com/CProperty/detail?num=1114099
# 75 / 276
# https://www.jejuall.com/CProperty/detail?num=819240
# 76 / 276
# https://www.jejuall.com/CProperty/detail?num=1115781
# 77 / 276
# https://www.jejuall.com/CProperty/detail?num=1115455
# 78 / 276
# https://www.jejuall.com/CProperty/detail?num=1048132
# 79 / 276
# https://www.jejuall.com/CProperty/detail?num=1091205
# 80 / 276
# https://www.jejuall.com/CProperty/detail?num=1115465
# 81 / 276
# https://www.jejuall.com/CProperty/detail?num=1100525
# 82 / 276
# https://www.jejuall.com/CProperty/detail?num=1104994
# 83 / 276
# https://www.jejuall.com/CProperty/detail?num=1105488
# 84 / 276
# https://www.jejuall.com/CProperty/detail?num=1115447
# 85 / 276
# https://www.jejuall.com/CProperty/detail?num=702695
# 86 / 276
# https://www.jejuall.com/CProperty/detail?num=1115463
# 87 / 276
# https://www.jejuall.com/CProperty/detail?num=1111413
# 88 / 276
# https://www.jejuall.com/CProperty/detail?num=698285
# 89 / 276
# https://www.jejuall.com/CProperty/detail?num=1068870
# 90 / 276
# https://www.jejuall.com/CProperty/detail?num=1104782
# 91 / 276
# https://www.jejuall.com/CProperty/detail?num=1107581
# 92 / 276
# https://www.jejuall.com/CProperty/detail?num=898009
# 93 / 276
# https://www.jejuall.com/CProperty/detail?num=1111420
# 94 / 276
# https://www.jejuall.com/CProperty/detail?num=952931
# 95 / 276
# https://www.jejuall.com/CProperty/detail?num=1084226
# 96 / 276
# https://www.jejuall.com/CProperty/detail?num=1112805
# 97 / 276
# https://www.jejuall.com/CProperty/detail?num=1111437
# 98 / 276
# https://www.jejuall.com/CProperty/detail?num=1111436
# 99 / 276
# https://www.jejuall.com/CProperty/detail?num=1094057
# 100 / 276
# https://www.jejuall.com/CProperty/detail?num=1113509
# 101 / 276
# https://www.jejuall.com/CProperty/detail?num=1115806
# 102 / 276
# https://www.jejuall.com/CProperty/detail?num=1113736
# 103 / 276
# https://www.jejuall.com/CProperty/detail?num=1112657
# 104 / 276
# https://www.jejuall.com/CProperty/detail?num=1096079
# 105 / 276
# https://www.jejuall.com/CProperty/detail?num=1111410
# 106 / 276
# https://www.jejuall.com/CProperty/detail?num=1115785
# 107 / 276
# https://www.jejuall.com/CProperty/detail?num=1101204
# 108 / 276
# https://www.jejuall.com/CProperty/detail?num=1115784
# 109 / 276
# https://www.jejuall.com/CProperty/detail?num=1111376
# 110 / 276
# https://www.jejuall.com/CProperty/detail?num=1112760
# 111 / 276
# https://www.jejuall.com/CProperty/detail?num=1115782
# 112 / 276
# https://www.jejuall.com/CProperty/detail?num=1111427
# 113 / 276
# https://www.jejuall.com/CProperty/detail?num=1001338
# 114 / 276
# https://www.jejuall.com/CProperty/detail?num=1101907
# 115 / 276
# https://www.jejuall.com/CProperty/detail?num=1115454
# 116 / 276
# https://www.jejuall.com/CProperty/detail?num=1034536
# 117 / 276
# https://www.jejuall.com/CProperty/detail?num=1060377
# 118 / 276
# https://www.jejuall.com/CProperty/detail?num=1110193
# 119 / 276
# https://www.jejuall.com/CProperty/detail?num=1112622
# 120 / 276
# https://www.jejuall.com/CProperty/detail?num=1115793
# 121 / 276
# https://www.jejuall.com/CProperty/detail?num=1115258
# 122 / 276
# https://www.jejuall.com/CProperty/detail?num=1111442
# 123 / 276
# https://www.jejuall.com/CProperty/detail?num=1111419
# 124 / 276
# https://www.jejuall.com/CProperty/detail?num=1115448
# 125 / 276
# https://www.jejuall.com/CProperty/detail?num=1115474
# 126 / 276
# https://www.jejuall.com/CProperty/detail?num=1115461
# 127 / 276
# https://www.jejuall.com/CProperty/detail?num=1109708
# 128 / 276
# https://www.jejuall.com/CProperty/detail?num=1115458
# 129 / 276
# https://www.jejuall.com/CProperty/detail?num=1100299
# 130 / 276
# https://www.jejuall.com/CProperty/detail?num=1111431
# 131 / 276
# https://www.jejuall.com/CProperty/detail?num=1088228
# 132 / 276
# https://www.jejuall.com/CProperty/detail?num=1115451
# 133 / 276
# https://www.jejuall.com/CProperty/detail?num=1106641
# 134 / 276
# https://www.jejuall.com/CProperty/detail?num=1115779
# 135 / 276
# https://www.jejuall.com/CProperty/detail?num=1085630
# 136 / 276
# https://www.jejuall.com/CProperty/detail?num=1081845
# 137 / 276
# https://www.jejuall.com/CProperty/detail?num=1115389
# 138 / 276
# https://www.jejuall.com/CProperty/detail?num=1084743
# 139 / 276
# https://www.jejuall.com/CProperty/detail?num=1107043
# 140 / 276
# https://www.jejuall.com/CProperty/detail?num=1108479
# 141 / 276
# https://www.jejuall.com/CProperty/detail?num=1071246
# 142 / 276
# https://www.jejuall.com/CProperty/detail?num=1090935
# 143 / 276
# https://www.jejuall.com/CProperty/detail?num=992658
# 144 / 276
# https://www.jejuall.com/CProperty/detail?num=932853
# 145 / 276
# https://www.jejuall.com/CProperty/detail?num=1111435
# 146 / 276
# https://www.jejuall.com/CProperty/detail?num=1111414
# 147 / 276
# https://www.jejuall.com/CProperty/detail?num=1103324
# 148 / 276
# https://www.jejuall.com/CProperty/detail?num=1103653
# 149 / 276
# https://www.jejuall.com/CProperty/detail?num=1107642
# 150 / 276
# https://www.jejuall.com/CProperty/detail?num=1111445
# 151 / 276
# https://www.jejuall.com/CProperty/detail?num=915730
# 152 / 276
# https://www.jejuall.com/CProperty/detail?num=1111429
# 153 / 276
# https://www.jejuall.com/CProperty/detail?num=1070592
# 154 / 276
# https://www.jejuall.com/CProperty/detail?num=577856
# 155 / 276
# https://www.jejuall.com/CProperty/detail?num=1115796
# 156 / 276
# https://www.jejuall.com/CProperty/detail?num=1107346
# 157 / 276
# https://www.jejuall.com/CProperty/detail?num=1114772
# 158 / 276
# https://www.jejuall.com/CProperty/detail?num=1111962
# 159 / 276
# https://www.jejuall.com/CProperty/detail?num=1115787
# 160 / 276
# https://www.jejuall.com/CProperty/detail?num=953822
# 161 / 276
# https://www.jejuall.com/CProperty/detail?num=952926
# 162 / 276
# https://www.jejuall.com/CProperty/detail?num=1115472
# 163 / 276
# https://www.jejuall.com/CProperty/detail?num=942617
# 164 / 276
# https://www.jejuall.com/CProperty/detail?num=1066614
# 165 / 276
# https://www.jejuall.com/CProperty/detail?num=1112273
# 166 / 276
# https://www.jejuall.com/CProperty/detail?num=1111432
# 167 / 276
# https://www.jejuall.com/CProperty/detail?num=950190
# 168 / 276
# https://www.jejuall.com/CProperty/detail?num=1111424
# 169 / 276
# https://www.jejuall.com/CProperty/detail?num=1094720
# 170 / 276
# https://www.jejuall.com/CProperty/detail?num=1113446
# 171 / 276
# https://www.jejuall.com/CProperty/detail?num=1115802
# 172 / 276
# https://www.jejuall.com/CProperty/detail?num=1101770
# 173 / 276
# https://www.jejuall.com/CProperty/detail?num=1113553
# 174 / 276
# https://www.jejuall.com/CProperty/detail?num=1111453
# 175 / 276
# https://www.jejuall.com/CProperty/detail?num=1114899
# 176 / 276
# https://www.jejuall.com/CProperty/detail?num=1114736
# 177 / 276
# https://www.jejuall.com/CProperty/detail?num=674095
# 178 / 276
# https://www.jejuall.com/CProperty/detail?num=1115450
# 179 / 276
# https://www.jejuall.com/CProperty/detail?num=914249
# 180 / 276
# https://www.jejuall.com/CProperty/detail?num=175223
# 181 / 276
# https://www.jejuall.com/CProperty/detail?num=316628
# 182 / 276
# https://www.jejuall.com/CProperty/detail?num=1095691
# 183 / 276
# https://www.jejuall.com/CProperty/detail?num=1086725
# 184 / 276
# https://www.jejuall.com/CProperty/detail?num=1115801
# 185 / 276
# https://www.jejuall.com/CProperty/detail?num=1114508
# 186 / 276
# https://www.jejuall.com/CProperty/detail?num=1001429
# 187 / 276
# https://www.jejuall.com/CProperty/detail?num=1027741
# 188 / 276
# https://www.jejuall.com/CProperty/detail?num=1115444
# 189 / 276
# https://www.jejuall.com/CProperty/detail?num=1115774
# 190 / 276
# https://www.jejuall.com/CProperty/detail?num=777381
# 191 / 276
# https://www.jejuall.com/CProperty/detail?num=1050427
# 192 / 276
# https://www.jejuall.com/CProperty/detail?num=1115800
# 193 / 276
# https://www.jejuall.com/CProperty/detail?num=810540
# 194 / 276
# https://www.jejuall.com/CProperty/detail?num=1115471
# 195 / 276
# https://www.jejuall.com/CProperty/detail?num=1070760
# 196 / 276
# https://www.jejuall.com/CProperty/detail?num=1115797
# 197 / 276
# https://www.jejuall.com/CProperty/detail?num=1086167
# 198 / 276
# https://www.jejuall.com/CProperty/detail?num=801828
# 199 / 276
# https://www.jejuall.com/CProperty/detail?num=1070053
# 200 / 276
# https://www.jejuall.com/CProperty/detail?num=1100185
# 201 / 276
# https://www.jejuall.com/CProperty/detail?num=755090
# 202 / 276
# https://www.jejuall.com/CProperty/detail?num=1023353
# 203 / 276
# https://www.jejuall.com/CProperty/detail?num=1115775
# 204 / 276
# https://www.jejuall.com/CProperty/detail?num=1093968
# 205 / 276
# https://www.jejuall.com/CProperty/detail?num=1115791
# 206 / 276
# https://www.jejuall.com/CProperty/detail?num=1111449
# 207 / 276
# https://www.jejuall.com/CProperty/detail?num=1115475
# 208 / 276
# https://www.jejuall.com/CProperty/detail?num=1087460
# 209 / 276
# https://www.jejuall.com/CProperty/detail?num=1115799
# 210 / 276
# https://www.jejuall.com/CProperty/detail?num=1100564
# 211 / 276
# https://www.jejuall.com/CProperty/detail?num=1075528
# 212 / 276
# https://www.jejuall.com/CProperty/detail?num=1115803
# 213 / 276
# https://www.jejuall.com/CProperty/detail?num=1115466
# 214 / 276
# https://www.jejuall.com/CProperty/detail?num=1115452
# 215 / 276
# https://www.jejuall.com/CProperty/detail?num=1093870
# 216 / 276
# https://www.jejuall.com/CProperty/detail?num=1115743
# 217 / 276
# https://www.jejuall.com/CProperty/detail?num=1102444
# 218 / 276
# https://www.jejuall.com/CProperty/detail?num=1112613
# 219 / 276
# https://www.jejuall.com/CProperty/detail?num=1111451
# 220 / 276
# https://www.jejuall.com/CProperty/detail?num=1115780
# 221 / 276
# https://www.jejuall.com/CProperty/detail?num=1064639
# 222 / 276
# https://www.jejuall.com/CProperty/detail?num=1113470
# 223 / 276
# https://www.jejuall.com/CProperty/detail?num=1115744
# 224 / 276
# https://www.jejuall.com/CProperty/detail?num=1111455
# 225 / 276
# https://www.jejuall.com/CProperty/detail?num=1114738
# 226 / 276
# https://www.jejuall.com/CProperty/detail?num=1030729
# 227 / 276
# https://www.jejuall.com/CProperty/detail?num=1115469
# 228 / 276
# https://www.jejuall.com/CProperty/detail?num=885280
# 229 / 276
# https://www.jejuall.com/CProperty/detail?num=1098764
# 230 / 276
# https://www.jejuall.com/CProperty/detail?num=1115794
# 231 / 276
# https://www.jejuall.com/CProperty/detail?num=1041990
# 232 / 276
# https://www.jejuall.com/CProperty/detail?num=1070958
# 233 / 276
# https://www.jejuall.com/CProperty/detail?num=1115453
# 234 / 276
# https://www.jejuall.com/CProperty/detail?num=1094041
# 235 / 276
# https://www.jejuall.com/CProperty/detail?num=973469
# 236 / 276
# https://www.jejuall.com/CProperty/detail?num=1075894
# 237 / 276
# https://www.jejuall.com/CProperty/detail?num=1115776
# 238 / 276
# https://www.jejuall.com/CProperty/detail?num=1107252
# 239 / 276
# https://www.jejuall.com/CProperty/detail?num=1115449
# 240 / 276
# https://www.jejuall.com/CProperty/detail?num=1111444
# 241 / 276
# https://www.jejuall.com/CProperty/detail?num=1070823
# 242 / 276
# https://www.jejuall.com/CProperty/detail?num=1115459
# 243 / 276
# https://www.jejuall.com/CProperty/detail?num=1089524
# 244 / 276
# https://www.jejuall.com/CProperty/detail?num=1106650
# 245 / 276
# https://www.jejuall.com/CProperty/detail?num=1115476
# 246 / 276
# https://www.jejuall.com/CProperty/detail?num=1115792
# 247 / 276
# https://www.jejuall.com/CProperty/detail?num=777511
# 248 / 276
# https://www.jejuall.com/CProperty/detail?num=1078300
# 249 / 276
# https://www.jejuall.com/CProperty/detail?num=1007562
# 250 / 276
# https://www.jejuall.com/CProperty/detail?num=1088091
# 251 / 276
# https://www.jejuall.com/CProperty/detail?num=1112255
# 252 / 276
# https://www.jejuall.com/CProperty/detail?num=1112665
# 253 / 276
# https://www.jejuall.com/CProperty/detail?num=1111439
# 254 / 276
# https://www.jejuall.com/CProperty/detail?num=1111422
# 255 / 276
# https://www.jejuall.com/CProperty/detail?num=1115468
# 256 / 276
# https://www.jejuall.com/CProperty/detail?num=1111454
# 257 / 276
# https://www.jejuall.com/CProperty/detail?num=952923
# 258 / 276
# https://www.jejuall.com/CProperty/detail?num=1115462
# 259 / 276
# https://www.jejuall.com/CProperty/detail?num=1103464
# 260 / 276
# https://www.jejuall.com/CProperty/detail?num=1055077
# 261 / 276
# https://www.jejuall.com/CProperty/detail?num=1101903
# 262 / 276
# https://www.jejuall.com/CProperty/detail?num=1075793
# 263 / 276
# https://www.jejuall.com/CProperty/detail?num=1112174
# 264 / 276
# https://www.jejuall.com/CProperty/detail?num=1112176
# 265 / 276
# https://www.jejuall.com/CProperty/detail?num=1115470
# 266 / 276
# https://www.jejuall.com/CProperty/detail?num=1081673
# 267 / 276
# https://www.jejuall.com/CProperty/detail?num=1111423
# 268 / 276
# https://www.jejuall.com/CProperty/detail?num=1070389
# 269 / 276
# https://www.jejuall.com/CProperty/detail?num=1100961
# 270 / 276
# https://www.jejuall.com/CProperty/detail?num=1115773
# 271 / 276
# https://www.jejuall.com/CProperty/detail?num=1081650
# 272 / 276
# https://www.jejuall.com/CProperty/detail?num=1115805
# 273 / 276
# https://www.jejuall.com/CProperty/detail?num=943152
# 274 / 276
# https://www.jejuall.com/CProperty/detail?num=1111447
# 275 / 276

# %%
tt = [item['detail_num'] for item in all_results]

# %%
df = pd.DataFrame(all_results)
df.to_csv('housing.csv')

# %%
check = list(set(tt))

# %%
no_dup = list(filter(lambda x: x['detail_num'] in check, all_results))

# %%
df = pd.DataFrame(no_dup)
df.drop_duplicates().to_csv('housing.csv')

# %%
df.drop_duplicates().shape
# Out:
# (160, 9)
